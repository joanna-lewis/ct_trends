# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# This script also contains the functions linking observed tests, symptomatic/asymptomatic/toal diagnoses, 
# incidence, prevalence, screening and other model parameters
# Running it takes a little while because of all the symbolic algebra
# %run -i test_diag_fun.py

# This script provides a function for calculating the likelihood of categorical data.
# %run -i multinomial_pmf.py

# This script samples model parameters from prior distributions, following the method in england.ipynb.
# %run -i sample_parameters.py

# %%
# now read in the local testing and diagnosis rates
import pandas as pd
from pandas import *
pd.options.mode.chained_assignment = None  # default='warn'

alldata = pd.read_csv('2013_age_sex_region.csv')
alldata = alldata[alldata.la != 'Isles of Scilly'] # remove Scilly Isles because of small numbers
alldata.index = range(len(alldata))
print alldata[['la','tests.male.15-19','positives.male.15-19', 'population.male.15-19']][:10]

# la: Local Authority (Upper Tier)
# gor: Government Office Region
# phec: Public Health England Region
# pher: Public Health England Centre
# Out:
#                      la  tests.male.15-19  positives.male.15-19  \
# 0  Barking and Dagenham            1439.0                  65.0
# 1                Barnet             442.0                  30.0
# 2                Bexley             677.0                  57.0
# 3                 Brent            1114.0                  81.0
# 4               Bromley            1151.0                  94.0
# 5                Camden            1227.0                  62.0
# 6        City of London               8.0                   NaN
# 7               Croydon            1472.0                 168.0
# 8                Ealing             561.0                  59.0
# 9               Enfield             569.0                  53.0
#
#    population.male.15-19
# 0                   6672
# 1                  10694
# 2                   7850
# 3                   9809
# 4                   9289
# 5                   5915
# 6                    113
# 7                  12161
# 8                   9660
# 9                  10808

# %%
# NB random state (rs) is set in sample_parameters.py, above.

# set up arrays to store, for each LA: 
test_sample_m = empty([n_sample, len(alldata)]) # testing rate
test_sample_f = empty([n_sample, len(alldata)])
diag_sample_m = empty([n_sample, len(alldata)]) # observed diagnosis rate
diag_sample_f = empty([n_sample, len(alldata)])
diag_m_la = empty([n_sample, len(alldata)]) # predicted diagnosis rate
diag_f_la = empty([n_sample, len(alldata)])

for i in xrange(len(alldata.index)):
    
    #####
    # men
    #####
    # sample for the testing rate, per sexually active 15-24-year-old
    test_sample_m[:,i] = rs.gamma(alldata['tests.male.total'][i],1,size = n_sample)/ \
        rs.binomial(alldata['population.male.15-19'][i] + alldata['population.male.20-24'][i], 
                        p_active_m_16_24, size=n_sample)
    diag_sample_m[:,i] = rs.gamma(alldata['positives.male.total'][i],1,size = n_sample)/ \
        rs.binomial(alldata['population.male.15-19'][i] + alldata['population.male.20-24'][i], 
                        p_active_m_16_24, size=n_sample)
        
    #####
    # women
    #####
    # sample for the testing rate, per sexually active 15-24-year-old
    test_sample_f[:,i] = rs.gamma(alldata['tests.female.total'][i],1,size = n_sample)/ \
        rs.binomial(alldata['population.female.15-19'][i] + alldata['population.female.20-24'][i], 
                        p_active_f_16_24, size=n_sample)
    diag_sample_f[:,i] = rs.gamma(alldata['positives.female.total'][i],1,size = n_sample)/ \
        rs.binomial(alldata['population.female.15-19'][i] + alldata['population.female.20-24'][i], 
                        p_active_f_16_24, size=n_sample)

# %%
# set up arrays to store, for each LA: 
scr_m_la = empty([n_sample, len(alldata)]) # screening (estimated for each LA separately)
scr_f_la = empty([n_sample, len(alldata)])
inc_m_la = empty([n_sample, len(alldata)])  # estimated incidence
inc_f_la = empty([n_sample, len(alldata)])
prev_m_la = empty([n_sample, len(alldata)]) # estimated prevalence
prev_f_la = empty([n_sample, len(alldata)])

for i in xrange(len(alldata.index)):
    
    # keep track of whether stuff is happening
    if fmod(i,10)==0:
        print i, alldata.la[i]
    
    #####
    # men
    #####
        
    # screening and diagnosis rates
    for j in xrange(n_sample):
        # local screening and incidence, given local testing and diagnoses
        [inc_m_la[j,i], scr_m_la[j,i]] = fsolve(lambda x: test_diag_fun(concatenate([
                        x, array([
                                1-p_asymp_m[j], # proportion of incident infections which are symptomatic
                                sc_m[j], # rate of self-clear 
                                att_symp[j],
                                p_true_pos_m[j], 
                                p_false_pos_m[j]
                            ])])) - array([test_sample_m[j,i],diag_sample_m[j,i]]), [0.09, 0.25])
        # local prevalence, calculated from local screening and incidence
        prev_m_la[j,i] = dyn_fun(
            inc_m_la[j,i]*p_asymp_m[j], 
            sc_m[j] + scr_m_la[j,i]*p_true_pos_m[j], 
            inc_m_la[j,i]*(1-p_asymp_m[j]), 
            scr_m_la[j,i]*p_true_pos_m[j] + att_symp[j]*p_true_pos_m[j]
        )
    
    #####
    # women
    #####

    # screening and diagnosis rates
    diag_f_la[:,i] = zeros(n_sample)
    for j in xrange(n_sample):
        # local screening and incidence, given local testing and diagnoses
        [inc_f_la[j,i], scr_f_la[j,i]] = fsolve(lambda x: test_diag_fun(concatenate([
                        x, array([
                                1-p_asymp_f[j], # proportion of incident infections which are symptomatic
                                sc_f[j], # rate of self-clear 
                                att_symp[j],
                                p_true_pos_f[j], 
                                p_false_pos_f[j]
                            ])])) - array([test_sample_f[j,i],diag_sample_f[j,i]]), [0.09, 0.25])
        # local prevalence, calculated from local screening and incidence
        prev_f_la[j,i] = dyn_fun(
            inc_f_la[j,i]*p_asymp_f[j], 
            sc_f[j] + scr_f_la[j,i]*p_true_pos_f[j], 
            inc_f_la[j,i]*(1-p_asymp_f[j]), 
            scr_f_la[j,i]*p_true_pos_f[j] + att_symp[j]*p_true_pos_f[j]
        )
# Out:
# 0 Barking and Dagenham
# 10 Greenwich
# 20 Kingston upon Thames
# 30 Waltham Forest
# 40 Derbyshire
# 50 Peterborough
# 60 Solihull
# 70 Halton
# 80 Lancashire
# 90 Wigan
# 100 South Tyneside
# 110 Leeds
# 120 Gloucestershire
# 130 Bournemouth
# 140 Medway
# 150 Wokingham
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/optimize/minpack.py:236: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %%
pid_data = pd.read_csv('PID_byarea.csv')
pid_data = pid_data[pid_data.Timeperiod == '2013/14']
pid_data = pid_data[pid_data.Sex == 'Female']
pid_data.index = range(len(pid_data))
print pid_data[:10]
# Out:
#    Unnamed: 0  IndicatorID                                      IndicatorName  \
# 0         811        90739  Pelvic inflammatory disease (PID) admissions r...
# 1         813        90739  Pelvic inflammatory disease (PID) admissions r...
# 2         814        90739  Pelvic inflammatory disease (PID) admissions r...
# 3         815        90739  Pelvic inflammatory disease (PID) admissions r...
# 4         816        90739  Pelvic inflammatory disease (PID) admissions r...
# 5         817        90739  Pelvic inflammatory disease (PID) admissions r...
# 6         818        90739  Pelvic inflammatory disease (PID) admissions r...
# 7         819        90739  Pelvic inflammatory disease (PID) admissions r...
# 8         820        90739  Pelvic inflammatory disease (PID) admissions r...
# 9         821        90739  Pelvic inflammatory disease (PID) admissions r...
#
#   ParentCode ParentName   AreaCode                         AreaName AreaType  \
# 0        NaN        NaN  E92000001                          England  Country
# 1  E92000001    England  E12000001                North East region   Region
# 2  E92000001    England  E12000002                North West region   Region
# 3  E92000001    England  E12000003  Yorkshire and the Humber region   Region
# 4  E92000001    England  E12000004             East Midlands region   Region
# 5  E92000001    England  E12000005             West Midlands region   Region
# 6  E92000001    England  E12000006           East of England region   Region
# 7  E92000001    England  E12000007                    London region   Region
# 8  E92000001    England  E12000008                South East region   Region
# 9  E92000001    England  E12000009                South West region   Region
#
#       Sex        Age         ...          UpperCI95.0limit  LowerCI99.8limit  \
# 0  Female  15-44 yrs         ...                238.631235               NaN
# 1  Female  15-44 yrs         ...                244.386802               NaN
# 2  Female  15-44 yrs         ...                283.845136               NaN
# 3  Female  15-44 yrs         ...                266.741148               NaN
# 4  Female  15-44 yrs         ...                257.453717               NaN
# 5  Female  15-44 yrs         ...                250.250372               NaN
# 6  Female  15-44 yrs         ...                218.064589               NaN
# 7  Female  15-44 yrs         ...                209.626618               NaN
# 8  Female  15-44 yrs         ...                238.728232               NaN
# 9  Female  15-44 yrs         ...                258.672931               NaN
#
#   UpperCI99.8limit    Count  Denominator  Valuenote  RecentTrend  \
# 0              NaN  25110.0   10653480.0        NaN          NaN
# 1              NaN   1147.0     497306.0        NaN          NaN
# 2              NaN   3794.0    1379867.0        NaN          NaN
# 3              NaN   2678.0    1042730.0        NaN          NaN
# 4              NaN   2166.0     877510.0        NaN          NaN
# 5              NaN   2642.0    1096784.0        NaN          NaN
# 6              NaN   2343.0    1118859.0        NaN          NaN
# 7              NaN   4079.0    2006490.0        NaN          NaN
# 8              NaN   3857.0    1667454.0        NaN          NaN
# 9              NaN   2402.0     966480.0        NaN          NaN
#
#    ComparedtoEnglandvalueorpercentiles  \
# 0                         Not compared
# 1                                 Same
# 2                                Worse
# 3                                Worse
# 4                                Worse
# 5                                 Same
# 6                               Better
# 7                               Better
# 8                                 Same
# 9                                Worse
#
#    Comparedtosubnationalparentvalueorpercentiles  TimeperiodSortable
# 0                                   Not compared            20130000
# 1                                   Not compared            20130000
# 2                                   Not compared            20130000
# 3                                   Not compared            20130000
# 4                                   Not compared            20130000
# 5                                   Not compared            20130000
# 6                                   Not compared            20130000
# 7                                   Not compared            20130000
# 8                                   Not compared            20130000
# 9                                   Not compared            20130000
#
# [10 rows x 25 columns]

# %%
list(alldata)
# Out:
# ['la',
#  'la_code',
#  'gor',
#  'phec',
#  'pher',
#  'tests.male.15-19',
#  'tests.male.20-24',
#  'tests.male.total',
#  'tests.female.15-19',
#  'tests.female.20-24',
#  'tests.female.total',
#  'tests.total.15-19',
#  'tests.total.20-24',
#  'tests.total',
#  'positives.male.15-19',
#  'positives.male.20-24',
#  'positives.male.total',
#  'positives.female.15-19',
#  'positives.female.20-24',
#  'positives.female.total',
#  'positives.total.15-19',
#  'positives.total.20-24',
#  'positives.total',
#  'population.male.15-19',
#  'population.male.20-24',
#  'population.female.15-19',
#  'population.female.20-24',
#  'population.total']

# %%
alldata = alldata.merge(pid_data, how='left', left_on = 'la_code', right_on = 'AreaCode')

# %%
alldata
# Out:
#                          la    la_code         gor  \
# 0      Barking and Dagenham  E09000002      london
# 1                    Barnet  E09000003      london
# 2                    Bexley  E09000004      london
# 3                     Brent  E09000005      london
# 4                   Bromley  E09000006      london
# 5                    Camden  E09000007      london
# 6            City of London  E09000001      london
# 7                   Croydon  E09000008      london
# 8                    Ealing  E09000009      london
# 9                   Enfield  E09000010      london
# 10                Greenwich  E09000011      london
# 11                  Hackney  E09000012      london
# 12   Hammersmith and Fulham  E09000013      london
# 13                 Haringey  E09000014      london
# 14                   Harrow  E09000015      london
# 15                 Havering  E09000016      london
# 16               Hillingdon  E09000017      london
# 17                 Hounslow  E09000018      london
# 18                Islington  E09000019      london
# 19   Kensington and Chelsea  E09000020      london
# 20     Kingston upon Thames  E09000021      london
# 21                  Lambeth  E09000022      london
# 22                 Lewisham  E09000023      london
# 23                   Merton  E09000024      london
# 24                   Newham  E09000025      london
# 25                Redbridge  E09000026      london
# 26     Richmond upon Thames  E09000027      london
# 27                Southwark  E09000028      london
# 28                   Sutton  E09000029      london
# 29            Tower Hamlets  E09000030      london
# ..                      ...        ...         ...
# 121          North Somerset  E06000024  south west
# 122   South Gloucestershire  E06000025  south west
# 123                 Swindon  E06000030  south west
# 124               Wiltshire  E06000054  south west
# 125                Cornwall  E06000052  south west
# 126                   Devon  E10000008  south west
# 127                Plymouth  E06000026  south west
# 128                Somerset  E10000027  south west
# 129                  Torbay  E06000027  south west
# 130             Bournemouth  E06000028  south west
# 131                  Dorset  E10000009  south west
# 132               Hampshire  E10000014  south east
# 133           Isle of Wight  E06000046  south east
# 134                   Poole  E06000029  south west
# 135              Portsmouth  E06000044  south east
# 136             Southampton  E06000045  south east
# 137       Brighton and Hove  E06000043  south east
# 138             East Sussex  E10000011  south east
# 139                    Kent  E10000016  south east
# 140                  Medway  E06000035  south east
# 141                  Surrey  E10000030  south east
# 142             West Sussex  E10000032  south east
# 143        Bracknell Forest  E06000036  south east
# 144         Buckinghamshire  E10000002  south east
# 145             Oxfordshire  E10000025  south east
# 146                 Reading  E06000038  south east
# 147                  Slough  E06000039  south east
# 148          West Berkshire  E06000037  south east
# 149  Windsor and Maidenhead  E06000040  south east
# 150               Wokingham  E06000041  south east
#
#                                   phec              pher  tests.male.15-19  \
# 0                               London            London            1439.0
# 1                               London            London             442.0
# 2                               London            London             677.0
# 3                               London            London            1114.0
# 4                               London            London            1151.0
# 5                               London            London            1227.0
# 6                               London            London               8.0
# 7                               London            London            1472.0
# 8                               London            London             561.0
# 9                               London            London             569.0
# 10                              London            London            2093.0
# 11                              London            London            1115.0
# 12                              London            London             306.0
# 13                              London            London             489.0
# 14                              London            London             387.0
# 15                              London            London            1147.0
# 16                              London            London            1890.0
# 17                              London            London            2181.0
# 18                              London            London             401.0
# 19                              London            London             426.0
# 20                              London            London             452.0
# 21                              London            London            1567.0
# 22                              London            London            1138.0
# 23                              London            London             558.0
# 24                              London            London            1495.0
# 25                              London            London            1404.0
# 26                              London            London             498.0
# 27                              London            London             936.0
# 28                              London            London             674.0
# 29                              London            London             502.0
# ..                                 ...               ...               ...
# 121  Avon, Gloucestershire & Wiltshire  South of England             543.0
# 122  Avon, Gloucestershire & Wiltshire  South of England             792.0
# 123  Avon, Gloucestershire & Wiltshire  South of England             491.0
# 124  Avon, Gloucestershire & Wiltshire  South of England             988.0
# 125         Devon, Cornwall & Somerset  South of England            1285.0
# 126         Devon, Cornwall & Somerset  South of England            2275.0
# 127         Devon, Cornwall & Somerset  South of England             628.0
# 128         Devon, Cornwall & Somerset  South of England               NaN
# 129         Devon, Cornwall & Somerset  South of England             341.0
# 130                             Wessex  South of England            1083.0
# 131                             Wessex  South of England            1902.0
# 132                             Wessex  South of England            4437.0
# 133                             Wessex  South of England             402.0
# 134                             Wessex  South of England             617.0
# 135                             Wessex  South of England            1908.0
# 136                             Wessex  South of England            1201.0
# 137              Kent, Surrey & Sussex  South of England            2438.0
# 138              Kent, Surrey & Sussex  South of England            1016.0
# 139              Kent, Surrey & Sussex  South of England            4788.0
# 140              Kent, Surrey & Sussex  South of England            1168.0
# 141              Kent, Surrey & Sussex  South of England            2143.0
# 142              Kent, Surrey & Sussex  South of England            2019.0
# 143                      Thames Valley  South of England             267.0
# 144                      Thames Valley  South of England             953.0
# 145                      Thames Valley  South of England            1619.0
# 146                      Thames Valley  South of England            1061.0
# 147                      Thames Valley  South of England             292.0
# 148                      Thames Valley  South of England             121.0
# 149                      Thames Valley  South of England             227.0
# 150                      Thames Valley  South of England             184.0
#
#      tests.male.20-24  tests.male.total  tests.female.15-19  \
# 0                1507            2946.0                2170
# 1                1448            1890.0                1510
# 2                1082            1759.0                1336
# 3                2822            3936.0                2362
# 4                1340            2491.0                2134
# 5                2546            3773.0                3055
# 6                  28              36.0                  13
# 7                2506            3978.0                3466
# 8                1571            2132.0                1583
# 9                1444            2013.0                1881
# 10               2790            4883.0                2546
# 11               3436            4551.0                3541
# 12               1588            1894.0                 867
# 13               1721            2210.0                1359
# 14                841            1228.0                1104
# 15               1265            2412.0                2137
# 16               2352            4242.0                2870
# 17               1786            3967.0                1519
# 18               1821            2222.0                1149
# 19               1372            1798.0                 919
# 20               1219            1671.0                1223
# 21               5358            6925.0                4122
# 22               2738            3876.0                2917
# 23               1244            1802.0                1123
# 24               2860            4355.0                2365
# 25               1576            2980.0                2042
# 26                959            1457.0                 980
# 27               3261            4197.0                2722
# 28               1050            1724.0                1597
# 29               2703            3205.0                1342
# ..                ...               ...                 ...
# 121               870            1413.0                2300
# 122              1189            1981.0                2625
# 123               968            1459.0                1962
# 124              2110            3098.0                3358
# 125              2408            3693.0                4153
# 126              4756            7031.0                6261
# 127              1769            2397.0                1728
# 128              1952               NaN                3897
# 129               701            1042.0                1214
# 130              1822            2905.0                2478
# 131              2337            4239.0                3307
# 132              5994           10431.0               10549
# 133               621            1023.0                1395
# 134               689            1306.0                1544
# 135              3395            5303.0                3761
# 136              2242            3443.0                2655
# 137              5531            7969.0                6150
# 138              1972            2988.0                4087
# 139              6064           10852.0               13666
# 140              1401            2569.0                2997
# 141              4302            6445.0                5288
# 142              3390            5409.0                5525
# 143               715             982.0                 732
# 144              1925            2878.0                2280
# 145              3275            4894.0                4139
# 146              1604            2665.0                2644
# 147               621             913.0                 864
# 148               400             521.0                 450
# 149               547             774.0                 871
# 150               489             673.0                 535
#
#      tests.female.20-24         ...          UpperCI95.0limit  \
# 0                  2637         ...                393.878584
# 1                  3657         ...                203.392894
# 2                  1912         ...                439.541105
# 3                  5421         ...                241.786925
# 4                  2896         ...                430.929774
# 5                  6678         ...                156.417550
# 6                    74         ...                       NaN
# 7                  5138         ...                341.883781
# 8                  3383         ...                173.353535
# 9                  3765         ...                261.643866
# 10                 3866         ...                267.809261
# 11                 7453         ...                211.015876
# 12                 2880         ...                195.381381
# 13                 3987         ...                236.013215
# 14                 2169         ...                265.087343
# 15                 2201         ...                348.759556
# 16                 3737         ...                260.632290
# 17                 2606         ...                207.966938
# 18                 4480         ...                285.691105
# 19                 2685         ...                117.475492
# 20                 2745         ...                172.756876
# 21                10278         ...                155.542466
# 22                 5798         ...                442.557039
# 23                 2381         ...                169.593434
# 24                 5615         ...                226.214867
# 25                 3096         ...                235.052585
# 26                 1919         ...                149.087701
# 27                 7168         ...                189.860823
# 28                 2118         ...                272.035828
# 29                 5876         ...                203.191460
# ..                  ...         ...                       ...
# 121                2584         ...                389.595858
# 122                3369         ...                292.355732
# 123                2100         ...                334.025413
# 124                4248         ...                234.947722
# 125                5517         ...                261.604371
# 126                8474         ...                301.053449
# 127                3520         ...                229.872173
# 128                5056         ...                238.054899
# 129                1434         ...                468.219727
# 130                3725         ...                288.112964
# 131                3480         ...                389.264008
# 132               12244         ...                253.577446
# 133                1850         ...                312.686320
# 134                1642         ...                429.108667
# 135                5310         ...                320.585281
# 136                4279         ...                354.852978
# 137                9725         ...                156.814361
# 138                5236         ...                243.045207
# 139               14509         ...                357.506495
# 140                3385         ...                435.998339
# 141                8736         ...                217.802977
# 142                7617         ...                233.142858
# 143                 932         ...                294.275097
# 144                3764         ...                159.959673
# 145                7073         ...                207.880237
# 146                3561         ...                205.305906
# 147                1404         ...                250.643903
# 148                 827         ...                163.224278
# 149                1148         ...                185.608422
# 150                 967         ...                154.347588
#
#      LowerCI99.8limit  UpperCI99.8limit  Count  Denominator  \
# 0                 NaN               NaN  149.0      44414.0
# 1                 NaN               NaN  141.0      81757.0
# 2                 NaN               NaN  181.0      47635.0
# 3                 NaN               NaN  151.0      73245.0
# 4                 NaN               NaN  238.0      62710.0
# 5                 NaN               NaN   76.0      60815.0
# 6                 NaN               NaN    NaN       1595.0
# 7                 NaN               NaN  243.0      80598.0
# 8                 NaN               NaN  113.0      78370.0
# 9                 NaN               NaN  158.0      70572.0
# 10                NaN               NaN  142.0      62496.0
# 11                NaN               NaN  130.0      73153.0
# 12                NaN               NaN   76.0      48687.0
# 13                NaN               NaN  130.0      65405.0
# 14                NaN               NaN  112.0      50838.0
# 15                NaN               NaN  139.0      47059.0
# 16                NaN               NaN  139.0      62971.0
# 17                NaN               NaN  104.0      60593.0
# 18                NaN               NaN  149.0      61233.0
# 19                NaN               NaN   30.0      36456.0
# 20                NaN               NaN   51.0      38815.0
# 21                NaN               NaN  112.0      86642.0
# 22                NaN               NaN  279.0      70891.0
# 23                NaN               NaN   63.0      47528.0
# 24                NaN               NaN  151.0      78287.0
# 25                NaN               NaN  127.0      64286.0
# 26                NaN               NaN   45.0      40388.0
# 27                NaN               NaN  130.0      81304.0
# 28                NaN               NaN   91.0      41071.0
# 29                NaN               NaN  136.0      79173.0
# ..                ...               ...    ...          ...
# 121               NaN               NaN  112.0      34591.0
# 122               NaN               NaN  125.0      50942.0
# 123               NaN               NaN  121.0      43284.0
# 124               NaN               NaN  168.0      83173.0
# 125               NaN               NaN  207.0      90672.0
# 126               NaN               NaN  337.0     124553.0
# 127               NaN               NaN  101.0      53388.0
# 128               NaN               NaN  184.0      89304.0
# 129               NaN               NaN   80.0      21265.0
# 130               NaN               NaN   95.0      40308.0
# 131               NaN               NaN  207.0      60936.0
# 132               NaN               NaN  557.0     238680.0
# 133               NaN               NaN   51.0      21445.0
# 134               NaN               NaN   92.0      26294.0
# 135               NaN               NaN  124.0      46117.0
# 136               NaN               NaN  174.0      56886.0
# 137               NaN               NaN   84.0      66319.0
# 138               NaN               NaN  182.0      86588.0
# 139               NaN               NaN  927.0     276540.0
# 140               NaN               NaN  210.0      55139.0
# 141               NaN               NaN  427.0     215556.0
# 142               NaN               NaN  298.0     143186.0
# 143               NaN               NaN   54.0      23943.0
# 144               NaN               NaN  127.0      94465.0
# 145               NaN               NaN  243.0     132553.0
# 146               NaN               NaN   61.0      38166.0
# 147               NaN               NaN   65.0      33054.0
# 148               NaN               NaN   33.0      28393.0
# 149               NaN               NaN   37.0      27477.0
# 150               NaN               NaN   32.0      29268.0
#
#                                          Valuenote  RecentTrend  \
# 0                                              NaN          NaN
# 1                                              NaN          NaN
# 2                                              NaN          NaN
# 3                                              NaN          NaN
# 4                                              NaN          NaN
# 5                                              NaN          NaN
# 6    Value for Hackney and City of London combined          NaN
# 7                                              NaN          NaN
# 8                                              NaN          NaN
# 9                                              NaN          NaN
# 10                                             NaN          NaN
# 11   Value for Hackney and City of London combined          NaN
# 12                                             NaN          NaN
# 13                                             NaN          NaN
# 14                                             NaN          NaN
# 15                                             NaN          NaN
# 16                                             NaN          NaN
# 17                                             NaN          NaN
# 18                                             NaN          NaN
# 19                                             NaN          NaN
# 20                                             NaN          NaN
# 21                                             NaN          NaN
# 22                                             NaN          NaN
# 23                                             NaN          NaN
# 24                                             NaN          NaN
# 25                                             NaN          NaN
# 26                                             NaN          NaN
# 27                                             NaN          NaN
# 28                                             NaN          NaN
# 29                                             NaN          NaN
# ..                                             ...          ...
# 121                                            NaN          NaN
# 122                                            NaN          NaN
# 123                                            NaN          NaN
# 124                                            NaN          NaN
# 125  Value for Cornwall & Isles of Scilly combined          NaN
# 126                                            NaN          NaN
# 127                                            NaN          NaN
# 128                                            NaN          NaN
# 129                                            NaN          NaN
# 130                                            NaN          NaN
# 131                                            NaN          NaN
# 132                                            NaN          NaN
# 133                                            NaN          NaN
# 134                                            NaN          NaN
# 135                                            NaN          NaN
# 136                                            NaN          NaN
# 137                                            NaN          NaN
# 138                                            NaN          NaN
# 139                                            NaN          NaN
# 140                                            NaN          NaN
# 141                                            NaN          NaN
# 142                                            NaN          NaN
# 143                                            NaN          NaN
# 144                                            NaN          NaN
# 145                                            NaN          NaN
# 146                                            NaN          NaN
# 147                                            NaN          NaN
# 148                                            NaN          NaN
# 149                                            NaN          NaN
# 150                                            NaN          NaN
#
#      ComparedtoEnglandvalueorpercentiles  \
# 0                                  Worse
# 1                                 Better
# 2                                  Worse
# 3                                   Same
# 4                                  Worse
# 5                                 Better
# 6                           Not compared
# 7                                  Worse
# 8                                 Better
# 9                                   Same
# 10                                  Same
# 11                                Better
# 12                                Better
# 13                                  Same
# 14                                  Same
# 15                                 Worse
# 16                                  Same
# 17                                Better
# 18                                  Same
# 19                                Better
# 20                                Better
# 21                                Better
# 22                                 Worse
# 23                                Better
# 24                                Better
# 25                                Better
# 26                                Better
# 27                                Better
# 28                                  Same
# 29                                Better
# ..                                   ...
# 121                                Worse
# 122                                 Same
# 123                                 Same
# 124                               Better
# 125                                 Same
# 126                                Worse
# 127                               Better
# 128                                 Same
# 129                                Worse
# 130                                 Same
# 131                                Worse
# 132                                 Same
# 133                                 Same
# 134                                Worse
# 135                                 Same
# 136                                Worse
# 137                               Better
# 138                                 Same
# 139                                Worse
# 140                                Worse
# 141                               Better
# 142                               Better
# 143                                 Same
# 144                               Better
# 145                               Better
# 146                               Better
# 147                                 Same
# 148                               Better
# 149                               Better
# 150                               Better
#
#      Comparedtosubnationalparentvalueorpercentiles  TimeperiodSortable
# 0                                            Worse            20130000
# 1                                             Same            20130000
# 2                                            Worse            20130000
# 3                                             Same            20130000
# 4                                            Worse            20130000
# 5                                           Better            20130000
# 6                                     Not compared            20130000
# 7                                            Worse            20130000
# 8                                           Better            20130000
# 9                                             Same            20130000
# 10                                            Same            20130000
# 11                                            Same            20130000
# 12                                          Better            20130000
# 13                                            Same            20130000
# 14                                            Same            20130000
# 15                                           Worse            20130000
# 16                                            Same            20130000
# 17                                            Same            20130000
# 18                                           Worse            20130000
# 19                                          Better            20130000
# 20                                          Better            20130000
# 21                                          Better            20130000
# 22                                           Worse            20130000
# 23                                          Better            20130000
# 24                                            Same            20130000
# 25                                            Same            20130000
# 26                                          Better            20130000
# 27                                          Better            20130000
# 28                                            Same            20130000
# 29                                          Better            20130000
# ..                                             ...                 ...
# 121                                          Worse            20130000
# 122                                           Same            20130000
# 123                                           Same            20130000
# 124                                         Better            20130000
# 125                                           Same            20130000
# 126                                           Same            20130000
# 127                                         Better            20130000
# 128                                         Better            20130000
# 129                                          Worse            20130000
# 130                                           Same            20130000
# 131                                          Worse            20130000
# 132                                           Same            20130000
# 133                                           Same            20130000
# 134                                          Worse            20130000
# 135                                           Same            20130000
# 136                                          Worse            20130000
# 137                                         Better            20130000
# 138                                           Same            20130000
# 139                                          Worse            20130000
# 140                                          Worse            20130000
# 141                                         Better            20130000
# 142                                           Same            20130000
# 143                                           Same            20130000
# 144                                         Better            20130000
# 145                                         Better            20130000
# 146                                         Better            20130000
# 147                                           Same            20130000
# 148                                         Better            20130000
# 149                                         Better            20130000
# 150                                         Better            20130000
#
# [151 rows x 53 columns]

# %%
fig = plt.figure(figsize = (5,5))
ax2 = fig.add_subplot(111)

# ax2.errorbar(
#     percentile(prev_f_la/(inc_f_la*(1-prev_f_la)), 50, 0), 
#     alldata['Value'],
#     xerr=squeeze(
#         array([[percentile(prev_f_la/(inc_f_la*(1-prev_f_la)),50, 0) - percentile(prev_f_la/(inc_f_la*(1-prev_f_la)), 2.5, 0)], 
#             [percentile(prev_f_la/(inc_f_la*(1-prev_f_la)), 97.5, 0) - percentile(prev_f_la/(inc_f_la*(1-prev_f_la)),50, 0)]])),
#     linestyle='None', color='r', alpha=0.2)
ax2.plot(
    percentile(prev_f_la/(inc_f_la*(1-prev_f_la)), 50, 0), 
    alldata['Value'],
    '.r')

#ax2.set_xlim([0,0.08])#; ax2.set_ylim([0,0.08])
#ax2.set_xlabel('Prevalence in sexually active women 15-24')
#ax2.set_ylabel('Positivity')
#ax2.set_title('Sexually active women 15-24')

# %%
al = prev_f_la/(inc_f_la*(1-prev_f_la))
print(shape(al))
print shape(transpose(tile(array(al[:,0],ndmin=2),[151,1])))
print percentile(array(al[:,0]), 50)
# Out:
# (10000, 151)
# (10000, 151)
# 0.576445977566

# %%
al = prev_f_la/(inc_f_la*(1-prev_f_la))
al_diff = al - transpose(tile(array(al[:,0],ndmin=2),[151,1]))

fig = plt.figure(figsize = (5,5))
ax2 = fig.add_subplot(111)

ax2.errorbar(
    percentile(al_diff, 50, 0), 
    alldata['Value'],
    xerr=squeeze(
        array([[percentile(al_diff,50, 0) - percentile(al_diff, 2.5, 0)], 
            [percentile(al_diff, 97.5, 0) - percentile(al_diff,50, 0)]])),
    linestyle='None', color='r', alpha=0.2)
ax2.plot(
    percentile(al_diff, 50, 0), 
    alldata['Value'],
    '.r')

#ax2.set_xlim([0,0.08])#; ax2.set_ylim([0,0.08])
#ax2.set_xlabel('Prevalence in sexually active women 15-24')
#ax2.set_ylabel('Positivity')
#ax2.set_title('Sexually active women 15-24')

# %%
plt.plot(percentile((inc_f_la*(1-prev_f_la)), 50, 0), percentile(prev_f_la, 50, 0), '.r')
plt.plot([0,1],[0,1])
plt.xlim([0,0.2])
plt.ylim([0,0.1])
# Out:
# (0, 0.1)

# %%
plt.plot(percentile(inc_f_la, 50, 0), percentile(prev_f_la/(inc_f_la*(1-prev_f_la)), 50, 0), '.r')

# %%
plt.plot(percentile(prev_f_la, 50, 0), percentile(prev_f_la/(inc_f_la*(1-prev_f_la)), 50, 0), '.r')
